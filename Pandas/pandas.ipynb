# %%
# Install Pandas
# !pip install pandas

# %%
# Import Pandas
import pandas as pd

# %%
# Check version
pd.__version__
# Out:
# '2.3.3'

# %%
# 1. Create Dataframe
df = pd.DataFrame([1,2,3],columns=['Col_Nameprint'])
print(df)
# Out:
#    Col_Nameprint
# 0              1
# 1              2
# 2              3

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data={
    "Name":["Abhishek","Abhay","Anuj","Aman"],
    "Age":[20,21,22,20],
    "Salary":[2000,3000,5000,9000]
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0  Abhishek   20    2000
# 1     Abhay   21    3000
# 2      Anuj   22    5000
# 3      Aman   20    9000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Basic DataFrame Understanding

# %%
df.head() # Top 5 Rows
# Out:
#        Name  Age  Salary
# 0  Abhishek   20    2000
# 1     Abhay   21    3000
# 2      Anuj   22    5000
# 3      Aman   20    9000

# %%
df.head(2) # Top 2 Rows
# Out:
#        Name  Age  Salary
# 0  Abhishek   20    2000
# 1     Abhay   21    3000

# %%
df.tail() # Bottom 5 Rows
# Out:
#        Name  Age  Salary
# 0  Abhishek   20    2000
# 1     Abhay   21    3000
# 2      Anuj   22    5000
# 3      Aman   20    9000

# %%
df.tail(2) # Bottom 2 Rows
# Out:
#    Name  Age  Salary
# 2  Anuj   22    5000
# 3  Aman   20    9000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Salary':'Monthly_Salary'},inplace=True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
df1=df.rename(columns={'Salary':'Monthly_Salary'})

# %%
df1
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   20.750000     4750.000000
# std     0.957427     3095.695937
# min    20.000000     2000.000000
# 25%    20.000000     2750.000000
# 50%    20.500000     4000.000000
# 75%    21.250000     6000.000000
# max    22.000000     9000.000000

# %%
# 3. Save and Load data from csv

# %%
df.to_csv('Test_data.csv',index=False) # Export DataFrame

# %%
load_df = pd.read_csv('Test_data.csv')  # Import DataFrame
load_df
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
# 4. Rows & Columns - Selection

# %%
# select columns
df[['Name']] # Single columns
# Out:
#        Name
# 0  Abhishek
# 1     Abhay
# 2      Anuj
# 3      Aman

# %%
df[['Name','Monthly_Salary']] # Multi columns
# Out:
#        Name  Monthly_Salary
# 0  Abhishek            2000
# 1     Abhay            3000
# 2      Anuj            5000
# 3      Aman            9000

# %%
# select rows
# loc - Label based indexing
# df.loc[df.Name=="Abhishek"]
df.loc[(df.Name=="Abhishek") & (df.Monthly_Salary>=2000)]
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000

# %%
df.loc[0:3]
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
# iloc - index-value based
df.iloc[0]
# Out:
# Name              Abhishek
# Age                     20
# Monthly_Salary        2000
# Name: 0, dtype: object

# %%
df.iloc[0:3]
# [start:stop:step]
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000

# %%
# 4. Filter Dataframe
df
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
df['Age']>20
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: Age, dtype: bool

# %%
df[df['Age']>=20]
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
df[(df['Age']>=21) & (df['Monthly_Salary']>=3000)]
# Out:
#     Name  Age  Monthly_Salary
# 1  Abhay   21            3000
# 2   Anuj   22            5000

# %%
df.where(df['Age']>20)
# Out:
#     Name   Age  Monthly_Salary
# 0    NaN   NaN             NaN
# 1  Abhay  21.0          3000.0
# 2   Anuj  22.0          5000.0
# 3    NaN   NaN             NaN

# %%
df.where(df['Age']>20,other='Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1         Abhay            21           3000
# 2          Anuj            22           5000
# 3  Not Eligible  Not Eligible   Not Eligible

# %%
# 6 Rows and Columns - Operations ( Add, Update, Delete)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0  Abhishek   20            2000
# 1     Abhay   21            3000
# 2      Anuj   22            5000
# 3      Aman   20            9000

# %%
# Add New Columns
df['Team']=['CEO','HR','CTO','DA']
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0  Abhishek   20            2000  CEO
# 1     Abhay   21            3000   HR
# 2      Anuj   22            5000  CTO
# 3      Aman   20            9000   DA

# %%
df['Bonus']=df['Monthly_Salary']*0.2
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0  Abhishek   20            2000  CEO   400.0
# 1     Abhay   21            3000   HR   600.0
# 2      Anuj   22            5000  CTO  1000.0
# 3      Aman   20            9000   DA  1800.0

# %%
# Add New Row
df.loc[len(df)]=['ABC',21,21000,'IT',2000]
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0  Abhishek   20            2000  CEO   400.0
# 1     Abhay   21            3000   HR   600.0
# 2      Anuj   22            5000  CTO  1000.0
# 3      Aman   20            9000   DA  1800.0
# 4       ABC   21           21000   IT  2000.0

# %%
len(df)
# Out:
# 5

# %%
# Update Value - using index name
df.loc[0,'Monthly_Salary']=95000
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0  Abhishek   20           95000  CEO   400.0
# 1     Abhay   21            3000   HR   600.0
# 2      Anuj   22            5000  CTO  1000.0
# 3      Aman   20            9000   DA  1800.0
# 4       ABC   21           21000   IT  2000.0

# %%
# Update Value - using columns name
df.loc[df.Name=="Abhay",'Monthly_Salary']=90000
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0  Abhishek   20           95000  CEO   400.0
# 1     Abhay   21           90000   HR   600.0
# 2      Anuj   22            5000  CTO  1000.0
# 3      Aman   20            9000   DA  1800.0
# 4       ABC   21           21000   IT  2000.0

# %%
# Delete Value - row and column values
df.drop(df[df.Name=='ABC'].index) # drop row, axis=0
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0  Abhishek   20           95000  CEO   400.0
# 1     Abhay   21           90000   HR   600.0
# 2      Anuj   22            5000  CTO  1000.0
# 3      Aman   20            9000   DA  1800.0

# %%
df.drop(4,axis=0) # index value
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0  Abhishek   20           95000  CEO   400.0
# 1     Abhay   21           90000   HR   600.0
# 2      Anuj   22            5000  CTO  1000.0
# 3      Aman   20            9000   DA  1800.0

# %%
df[df.Name=='ABC']
# Out:
#   Name  Age  Monthly_Salary Team   Bonus
# 4  ABC   21           21000   IT  2000.0

# %%
df.drop('Bonus',axis=1, inplace=True) # drop column

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0  Abhishek   20           95000  CEO
# 1     Abhay   21           90000   HR
# 2      Anuj   22            5000  CTO
# 3      Aman   20            9000   DA
# 4       ABC   21           21000   IT

# %%
# df.drop(['Bonus','Team'],axis=1) # drop multiple columns

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0  Abhishek   20           95000  CEO
# 1     Abhay   21           90000   HR
# 2      Anuj   22            5000  CTO
# 3      Aman   20            9000   DA
# 4       ABC   21           21000   IT

# %%
# Sort Value
df.sort_values('Monthly_Salary',ascending=False) # Descending Order
# Out:
#        Name  Age  Monthly_Salary Team
# 0  Abhishek   20           95000  CEO
# 1     Abhay   21           90000   HR
# 4       ABC   21           21000   IT
# 3      Aman   20            9000   DA
# 2      Anuj   22            5000  CTO

# %%
# Working with date value

# %%
df['DOJ']=['2024-01-01','2024-01-15','2024-03-28','2024-03-03','2024-05-02']
df
# Out:
#        Name  Age  Monthly_Salary Team         DOJ
# 0  Abhishek   20           95000  CEO  2024-01-01
# 1     Abhay   21           90000   HR  2024-01-15
# 2      Anuj   22            5000  CTO  2024-03-28
# 3      Aman   20            9000   DA  2024-03-03
# 4       ABC   21           21000   IT  2024-05-02

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
df['DOJ']=pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')
